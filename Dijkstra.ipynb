# %%
from collections import defaultdict, deque

# %%
class Graph(object):
    def __init__(self):
        self.nodes = set()
        self.edges = defaultdict(list)
        self.distances = {}

    def add_node(self, value):
        self.nodes.add(value)

    def add_edge(self, from_node, to_node, distance):
        self.edges[from_node].append(to_node)
        self.edges[to_node].append(from_node)
        self.distances[(from_node, to_node)] = distance

# %%
def dijkstra(graph, initial):
    visited = {initial: 0}
    path = {}

    nodes = set(graph.nodes)

    while nodes:
        min_node = None
        for node in nodes:
            if node in visited:
                if min_node is None:
                    min_node = node
                elif visited[node] < visited[min_node]:
                    min_node = node
        if min_node is None:
            break

        nodes.remove(min_node)
        current_weight = visited[min_node]

        for edge in graph.edges[min_node]:
            try:
                weight = current_weight + graph.distances[(min_node, edge)]
            except:
                continue
            if edge not in visited or weight < visited[edge]:
                visited[edge] = weight
                path[edge] = min_node

    return visited, path

# %%
def shortest_path(graph, origin, destination):
    visited, paths = dijkstra(graph, origin)
    full_path = deque()
    _destination = paths[destination]

    while _destination != origin:
        full_path.appendleft(_destination)
        _destination = paths[_destination]

    full_path.appendleft(origin)
    full_path.append(destination)

    return visited[destination], list(full_path)

# %%
if __name__ == '__main__':
  graph = Graph()
  nodelist = ['A1', 'A2', 'A3', 'A4', 'B1', 'B2', 'C1', 'C2', 'C3', 'C4', 'D1', 'D2', 'D2', 'D3', 'D4', 'E1', 'E2', 'E3', 'E4', 'L1', 'L2', 'P1', 'P2', 'P3', 'P4']

  for node in nodelist:
    graph.add_node(node)

    graph.add_edge('A1', 'A2', 20)
    graph.add_edge('A2', 'A1', 20)

    graph.add_edge('A1', 'P1', 50)
    graph.add_edge('P1', 'A1', 50)

    graph.add_edge('A2', 'A3', 20)
    graph.add_edge('A3', 'A2', 20)

    graph.add_edge('A2', 'P2', 45)
    graph.add_edge('P2', 'A2', 45)

    graph.add_edge('A3', 'A4', 20)
    graph.add_edge('A4', 'A3', 20)

    graph.add_edge('A3', 'D3', 15)
    graph.add_edge('D3', 'A3', 15)

    graph.add_edge('A3', 'L1', 40)
    graph.add_edge('L1', 'A3', 40)

    graph.add_edge('A4', 'D4', 15)
    graph.add_edge('D4', 'A4', 15)

    graph.add_edge('A4', 'P4', 45)
    graph.add_edge('P4', 'A4', 45)

    graph.add_edge('B1', 'C1', 50)
    graph.add_edge('C1', 'B1', 50)

    graph.add_edge('C2', 'B2', 50)
    graph.add_edge('B2', 'C2', 50)

    graph.add_edge('B2', 'E2', 15)
    graph.add_edge('E2', 'B2', 15)

    graph.add_edge('C1', 'C2', 20)
    graph.add_edge('C2', 'C1', 20)

    graph.add_edge('C2', 'C3', 20)
    graph.add_edge('C3', 'C2', 20)

    graph.add_edge('C3', 'C4', 20)
    graph.add_edge('C4', 'C3', 20)

    graph.add_edge('C3', 'L2', 20)
    graph.add_edge('L2', 'C3', 20)

    graph.add_edge('C4', 'E4', 65) 
    graph.add_edge('E4', 'C4', 65) 

    graph.add_edge('D1', 'D2', 20)
    graph.add_edge('D2', 'D1', 20)

    graph.add_edge('D2', 'D3', 20)
    graph.add_edge('D3', 'D2', 20)

    graph.add_edge('D2', 'E2', 40)
    graph.add_edge('E2', 'D2', 40)

    graph.add_edge('D3', 'D4', 20)
    graph.add_edge('D4', 'D3', 20)

    graph.add_edge('D3', 'E3', 40)
    graph.add_edge('E3', 'D3', 40)

    graph.add_edge('D4', 'E4', 40)
    graph.add_edge('E4', 'D4', 40)

    graph.add_edge('E1', 'E2', 20)
    graph.add_edge('E2', 'E1', 20)

    graph.add_edge('E2', 'E3', 20)
    graph.add_edge('E3', 'E2', 20)

    graph.add_edge('E3', 'E4', 20)
    graph.add_edge('E4', 'E3', 20)

    graph.add_edge('E3', 'L2', 45)
    graph.add_edge('L2', 'E3', 45)

    graph.add_edge('P1', 'P2', 20)
    graph.add_edge('P2', 'P1', 20)

    graph.add_edge('P2', 'P3', 20)
    graph.add_edge('P3', 'P2', 20)

    graph.add_edge('P3', 'P4', 20)
    graph.add_edge('P4', 'P3', 20)
    graph.add_edge('P3', 'L1', 5)
    graph.add_edge('L1', 'P3', 5)

    graph.add_edge('L1', 'L2', 40)
    graph.add_edge('L2', 'L1', 40)

# %%
current = input(['현재 위치: '])
# Out:
# ['현재 위치: ']P201

# %%
if current == 'P101':
  graph.add_node('P101')
  graph.add_edge('P101', 'A1', 5)
  graph.add_edge('P101', 'P1', 45)
  add_edges()
if current == 'P102':
  graph.add_node('P102')
  graph.add_edge('P102', 'A1', 12)
  graph.add_edge('P102', 'P1', 38)
if current == 'P103':
  graph.add_node('P103')
  graph.add_edge('P103', 'A1', 19)
  graph.add_edge('P103', 'P1', 31)
if current == 'P104':
  graph.add_node('P104')
  graph.add_edge('P104', 'A1', 26)
  graph.add_edge('P104', 'P1', 24)
if current == 'P105':
  graph.add_node('P105')
  graph.add_edge('P105', 'A1', 13)
  graph.add_edge('P105', 'P1', 37)
if current == 'P106':
  graph.add_node('P106')
  graph.add_edge('P106', 'A1', 10)
  graph.add_edge('P106', 'P1', 40)
if current == 'P107':
  graph.add_node('P107')
  graph.add_edge('P107', 'A1', 7)
  graph.add_edge('P107', 'P1', 43)

if current == 'P201':
  graph.add_node('P201')
  graph.add_edge('P201', 'A2', 1)
  graph.add_edge('P201', 'P2', 44)
if current == 'P202':
  graph.add_node('P202')
  graph.add_edge('P202', 'A2', 6)
  graph.add_edge('P202', 'P2', 39)
if current == 'P203':
  graph.add_node('P203')
  graph.add_edge('P203', 'A2', 15)
  graph.add_edge('P203', 'P2', 30)
if current == 'P204':
  graph.add_node('P204')
  graph.add_edge('P204', 'A2', 20)
  graph.add_edge('P204', 'P2', 25)
if current == 'P205':
  graph.add_node('P205')
  graph.add_edge('P205', 'A2', 25)
  graph.add_edge('P205', 'P2', 20)
if current == 'P206':
  graph.add_node('P206')
  graph.add_edge('P206', 'A2', 30)
  graph.add_edge('P206', 'P2', 15)
if current == 'P207':
  graph.add_node('P207')
  graph.add_edge('P207', 'A2', 35)
  graph.add_edge('P207', 'P2', 10)
if current == 'P208':
  graph.add_node('P208')
  graph.add_edge('P208', 'A2', 7)
  graph.add_edge('P208', 'P2', 38)
if current == 'P209':
  graph.add_node('P209')
  graph.add_edge('P209', 'A2', 4)
  graph.add_edge('P209', 'P2', 41)
if current == 'P210':
  graph.add_node('P210')
  graph.add_edge('P210', 'A2', 1)
  graph.add_edge('P210', 'P2', 44)

if current == 'P301':
  graph.add_node('P301')
  graph.add_edge('P301', 'A3', 1)
  graph.add_edge('P301', 'L1', 44)
if current == 'P302':
  graph.add_node('P302')
  graph.add_edge('P302', 'A3', 9)
  graph.add_edge('P302', 'L1', 36)
if current == 'P303':
  graph.add_node('P303')
  graph.add_edge('P303', 'A3', 17)
  graph.add_edge('P303', 'L1', 28)
if current == 'P304':
  graph.add_node('P304')
  graph.add_edge('P304', 'A3', 25)
  graph.add_edge('P304', 'L1', 20)
if current == 'P305':
  graph.add_node('P305')
  graph.add_edge('P305', 'A3', 33)
  graph.add_edge('P305', 'L1', 12)
if current == 'P306':
  graph.add_node('P306')
  graph.add_edge('P306', 'P3', 2)
  graph.add_edge('P306', 'L1', 3)
if current == 'P307':
  graph.add_node('P307')
  graph.add_edge('P307', 'A3', 7)
  graph.add_edge('P307', 'L1', 38)
if current == 'P308':
  graph.add_node('P308')
  graph.add_edge('P308', 'A3', 4)
  graph.add_edge('P308', 'L1', 41)
if current == 'P309':
  graph.add_node('P309')
  graph.add_edge('P309', 'A3', 1)
  graph.add_edge('P309', 'L1', 44)

if current == 'P401':
  graph.add_node('P401')
  graph.add_edge('P401', 'A4', 1)
  graph.add_edge('P401', 'P4', 44)
if current == 'P402':
  graph.add_node('P402')
  graph.add_edge('P402', 'A4', 8)
  graph.add_edge('P402', 'P4', 37)
if current == 'P403':
  graph.add_node('P403')
  graph.add_edge('P403', 'A4', 15)
  graph.add_edge('P403', 'P4', 30)
if current == 'P404':
  graph.add_node('P404')
  graph.add_edge('P404', 'A4', 22)
  graph.add_edge('P404', 'P4', 23)
if current == 'P405':
  graph.add_node('P405')
  graph.add_edge('P405', 'A4', 30)
  graph.add_edge('P405', 'P4', 15)
if current == 'P406':
  graph.add_node('P406')
  graph.add_edge('P406', 'A4', 37)
  graph.add_edge('P406', 'P4', 8)
if current == 'P407':
  graph.add_node('P407')
  graph.add_edge('P407', 'A4', 41)
  graph.add_edge('P407', 'P4', 4)
if current == 'P408':
  graph.add_node('P408')
  graph.add_edge('P408', 'A4', 7)
  graph.add_edge('P408', 'P4', 38)
if current == 'P409':
  graph.add_node('P409')
  graph.add_edge('P409', 'A4', 4)
  graph.add_edge('P409', 'P4', 41)
if current == 'P410':
  graph.add_node('P410')
  graph.add_edge('P410', 'A4', 1)
  graph.add_edge('P410', 'P4', 44)

if current == 'C102':
  graph.add_node('C102')
  graph.add_edge('C102', 'B1', 1)
  graph.add_edge('C102', 'C1', 44)
if current == 'C103':
  graph.add_node('C103')
  graph.add_edge('C103', 'B1', 8)
  graph.add_edge('C103', 'C1', 37)
if current == 'C104':
  graph.add_node('C104')
  graph.add_edge('C104', 'B1', 15)
  graph.add_edge('C104', 'C1', 30)
if current == 'C105':
  graph.add_node('C105')
  graph.add_edge('C105', 'B1', 22)
  graph.add_edge('C105', 'C1', 23)
if current == 'C106':
  graph.add_node('C106')
  graph.add_edge('C106', 'B1', 30)
  graph.add_edge('C106', 'C1', 15)
if current == 'C107':
  graph.add_node('C107')
  graph.add_edge('C107', 'B1', 37)
  graph.add_edge('C107', 'C1', 8)
if current == 'C108':
  graph.add_node('C108')
  graph.add_edge('C108', 'B1', 41)
  graph.add_edge('C108', 'C1', 4)
if current == ' C109':
  graph.add_node('C109')
  graph.add_edge('C109', 'B1', 28)
  graph.add_edge('C109', 'C1', 17)
if current == ' C110':
  graph.add_node('C110')
  graph.add_edge('C110', 'B1', 24)
  graph.add_edge('C110', 'C1', 21)

if current == 'C201':
  graph.add_node('C201')
  graph.add_edge('C201', 'E2', 4)
  graph.add_edge('C201', 'B2', 4)
if current == 'C202':
  graph.add_node('C202')
  graph.add_edge('C202', 'E2', 5)
  graph.add_edge('C202', 'B2', 1)
if current == 'C203':
  graph.add_node('C203')
  graph.add_edge('C203', 'E2', 12)
  graph.add_edge('C203', 'B2', 8)
if current == 'C204':
  graph.add_node('C204')
  graph.add_edge('C204', 'E2', 19)
  graph.add_edge('C204', 'B2', 15)
if current == 'C205':
  graph.add_node('C205')
  graph.add_edge('C205', 'B2', 22)
  graph.add_edge('C205', 'C2', 17)
if current == 'C206':
  graph.add_node('C206')
  graph.add_edge('C206', 'B2', 29)
  graph.add_edge('C206', 'C2', 11)
if current == 'C207':
  graph.add_node('C207')
  graph.add_edge('C207', 'B2', 36)
  graph.add_edge('C207', 'C2', 7)
if current == 'C208':
  graph.add_node('C208')
  graph.add_edge('C208', 'B2', 46)
  graph.add_edge('C208', 'C2', 4)
if current == 'C209':
  graph.add_node('C209')
  graph.add_edge('C209', 'B2', 28)
  graph.add_edge('C209', 'C2', 18)
if current == 'C210':
  graph.add_node('C210')
  graph.add_edge('C210', 'B2', 24)
  graph.add_edge('C210', 'C2', 22)

if current == 'C301':
  graph.add_node('C301')
  graph.add_edge('C301', 'E3', 5)
  graph.add_edge('C301', 'L2', 56)
if current == 'C302':
  graph.add_node('C302')
  graph.add_edge('C302', 'E3', 8)
  graph.add_edge('C302', 'L2', 49)
if current == 'C303':
  graph.add_node('C303')
  graph.add_edge('C303', 'E3', 4)
  graph.add_edge('C303', 'L2', 42)
if current == 'C304':
  graph.add_node('C304')
  graph.add_edge('C304', 'E3', 7)
  graph.add_edge('C304', 'L2', 35)
if current == 'C305':
  graph.add_node('C305')
  graph.add_edge('C305', 'E3', 14)
  graph.add_edge('C305', 'L2', 28)
if current == 'C306':
  graph.add_node('C306')
  graph.add_edge('C306', 'C3', 53)
  graph.add_edge('C306', 'L2', 21)
if current == 'C307':
  graph.add_node('C307')
  graph.add_edge('C307', 'C3', 46)
  graph.add_edge('C307', 'L2', 14)
if current == 'C308':
  graph.add_node('C308')
  graph.add_edge('C308', 'C3', 39)
  graph.add_edge('C308', 'L2', 7)
if current == 'C309':
  graph.add_node('C309')
  graph.add_edge('C309', 'C3', 32)
  graph.add_edge('C309', 'L2', 1)
if current == 'C310':
  graph.add_node('C310')
  graph.add_edge('C310', 'C3', 25)
  graph.add_edge('C310', 'L2', 1)
if current == 'C311':
  graph.add_node('C311')
  graph.add_edge('C311', 'C3', 11)
  graph.add_edge('C311', 'L2', 8)
if current == 'C312':
  graph.add_node('C312')
  graph.add_edge('C312', 'C3', 4)
  graph.add_edge('C312', 'L2', 15)
if current == 'C313':
  graph.add_node('C313')
  graph.add_edge('C313', 'E3', 11)
  graph.add_edge('C313', 'L2', 32)
if current == 'C314':
  graph.add_node('C314')
  graph.add_edge('C314', 'C3', 15)
  graph.add_edge('C314', 'L2', 36)

if current == 'C401':
  graph.add_node('C401')
  graph.add_edge('C401', 'E4', 5)
  graph.add_edge('C401', 'C4', 81)
if current == 'C402':
  graph.add_node('C402')
  graph.add_edge('C402', 'E4', 8)
  graph.add_edge('C402', 'C4', 74)
if current == 'C403':
  graph.add_node('C403')
  graph.add_edge('C403', 'E4', 4)
  graph.add_edge('C403', 'C4', 67)
if current == 'C404':
  graph.add_node('C404')
  graph.add_edge('C404', 'E4', 7)
  graph.add_edge('C404', 'C4', 60)
if current == 'C405':
  graph.add_node('C405')
  graph.add_edge('C405', 'E4', 18)
  graph.add_edge('C405', 'C4', 53)
if current == 'C406':
  graph.add_node('C406')
  graph.add_edge('C406', 'E4', 25)
  graph.add_edge('C406', 'C4', 46)
if current == 'C407':
  graph.add_node('C407')
  graph.add_edge('C407', 'E4', 32)
  graph.add_edge('C407', 'C4', 39)
if current == 'C408':
  graph.add_node('C408')
  graph.add_edge('C408', 'E4', 39)
  graph.add_edge('C408', 'C4', 32)
if current == 'C409':
  graph.add_node('C409')
  graph.add_edge('C409', 'E4', 46)
  graph.add_edge('C409', 'C4', 25)
if current == 'C410':
  graph.add_node('C410')
  graph.add_edge('C410', 'E4', 53)
  graph.add_edge('C410', 'C4', 18)
if current == 'C411':
  graph.add_node('C411')
  graph.add_edge('C411', 'E4', 60)
  graph.add_edge('C411', 'C4', 11)
if current == 'C412':
  graph.add_node('C412')
  graph.add_edge('C412', 'E4', 67)
  graph.add_edge('C412', 'C4', 4)
if current == 'C413':
  graph.add_node('C413')
  graph.add_edge('C413', 'E4', 39)
  graph.add_edge('C413', 'C4', 32)
if current == 'C414':
  graph.add_node('C414')
  graph.add_edge('C414', 'E4', 35)
  graph.add_edge('C414', 'C4', 36)
if current == 'D201':
  graph.add_node('D201')
  graph.add_edge('D201', 'D2', 11)
  graph.add_edge('D201', 'E2', 35)
if current == 'D202':
  graph.add_node('D202')
  graph.add_edge('D202', 'D2', 7)
  graph.add_edge('D202', 'E2', 28)
if current == 'D203':
  graph.add_node('D203')
  graph.add_edge('D203', 'D2', 11)
  graph.add_edge('D203', 'E2', 21)
if current == 'D204':
  graph.add_node('D204')
  graph.add_edge('D204', 'D2', 7)
  graph.add_edge('D204', 'E2', 35)
if current == 'D205':
  graph.add_node('D205')
  graph.add_edge('D205', 'D2', 7)
  graph.add_edge('D205', 'E2', 21)
if current == 'D206':
  graph.add_node('D206')
  graph.add_edge('D206', 'B2', 15)
  graph.add_edge('D206', 'E2', 8)
if current == 'D207':
  graph.add_node('D207')
  graph.add_edge('D207', 'B2', 11)
graph.add_edge('D207', 'E2', 4)

if current == 'D301':
  graph.add_node('D301')
  graph.add_edge('D301', 'D3', 11)
  graph.add_edge('D301', 'A3', 14)
if current == 'D302':
  graph.add_node('D302')
  graph.add_edge('D302', 'D3', 7)
  graph.add_edge('D302', 'A3', 11)
if current == 'D303':
  graph.add_node('D303')
  graph.add_edge('D303', 'D3', 11)
  graph.add_edge('D303', 'A3', 14)
if current == 'D304':
  graph.add_node('D304')
  graph.add_edge('D304', 'D3', 4)
  graph.add_edge('D304', 'A3', 18)
if current == 'D305':
  graph.add_node('D305')
  graph.add_edge('D305', 'D3', 14)
  graph.add_edge('D305', 'E3', 14)
if current == 'D306':
  graph.add_node('D306')
  graph.add_edge('D306', 'D3', 15)
  graph.add_edge('D306', 'E3', 8)
if current == 'D307':
  graph.add_node('D307')
  graph.add_edge('D307', 'D3', 19)
  graph.add_edge('D307', 'E3', 4)

if current == 'D401':
  graph.add_node('D401')
  graph.add_edge('D401', 'D4', 11)
  graph.add_edge('D401', 'A4', 14)
if current == 'D402':
  graph.add_node('D402')
  graph.add_edge('D402', 'D4', 7)
  graph.add_edge('D402', 'A4', 11)
if current == 'D403':
  graph.add_node('D403')
  graph.add_edge('D403', 'D4', 4)
  graph.add_edge('D403', 'A4', 18)
if current == 'D404':
  graph.add_node('D404')
  graph.add_edge('D404', 'D4', 14)
  graph.add_edge('D404', 'E4', 14)
if current == 'D405':
  graph.add_node('D405')
  graph.add_edge('D405', 'D4', 15)
  graph.add_edge('D405', 'E4', 8)
if current == 'D406':
  graph.add_node('D406')
  graph.add_edge('D406', 'D4', 19)
  graph.add_edge('D406', 'E4', 4)

# %%
toa = shortest_path(graph, current, 'A1')

# %%
tob = shortest_path(graph, current, 'B1')

# %%
toc = shortest_path(graph, current, 'C1')

# %%
tod = shortest_path(graph, current, 'D1')

# %%
toe = shortest_path(graph, current, 'E1')

# %%
top = shortest_path(graph, current, 'P1')

# %%
print(min(toa,tob,toc,tod,toe,top))
# Out:
# (21, ['P201', 'A2', 'A1'])
